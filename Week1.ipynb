# %%
type(True)
# Out:
# <class 'bool'>

# %%
type(False)
# Out:
# <class 'bool'>

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
"hello" + "" + "there"
# Out:
# hellothere

# %%
"hello" + " " + "there"
# Out:
# hello there

# %%
"bye bye" + ' ' + 'here'
# Out:
# bye bye here

# %%
"blah" * 3
# Out:
# blahblahblah

# %%
["a", "b"] + ['c', 'd']
# Out:
# ['a', 'b', 'c', 'd']

# %%
['1', '2'] * 3
# Out:
# ['1', '2', '1', '2', '1', '2']

# %%
("x", "y") + ("z")
# Out:
# Traceback (most recent call last):
#   File "/Users/jamesobrien/.vscode/extensions/ms-python.python-2026.0.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
(2, 4, 6) * 10
# Out:
# (2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6, 2, 4, 6)

# %%
"hello"[1]
# Out:
# e

# %%
["a", "b", "c"][2]
# Out:
# c

# %%
(2, 4, 6, 8, 10)[-2]
# Out:
# 8

# %%
'weather'[1:4]
# Out:
# eat

# %%
["he", "said", "he", "was", "cold"][2:]
# Out:
# ['he', 'was', 'cold']

# %%
["one", "two", "three", "four", "five"][:3]
# Out:
# ['one', 'two', 'three']

# %%
'Alpha' < 'alpha'
# Out:
# True

# %%
'banana' > 'apple'
# Out:
# True

# %%
'a1' > 'a2'
# Out:
# False

# %%
[1, 2] < [2, 2]
# Out:
# True

# %%
[1, 2] < [1, 3]
# Out:
# True

# %%
[1] < [1, 4]
# Out:
# True

# %%
[1, 2] < [1, "2"]
# Out:
# Traceback (most recent call last):
#   File "/Users/jamesobrien/.vscode/extensions/ms-python.python-2026.0.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# TypeError: '<' not supported between instances of 'int' and 'str'
